# %%
#Step 1: Import Necessary Libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math
import time

from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model

# %%
#Step 2: Image processing
def load_and_process_image(image_path):
    img = load_img(image_path)

    img = img_to_array(img)
    img = preprocess_input(img)
    img = np.expand_dims(img, axis=0)
    return img

# %%
def deprocess(img):
    img[:, :, 0] += 103.939
    img[:, :, 1] += 116.779
    img[:, :, 2] += 123.6
    img = img[:, :, ::-1]

    img = np.clip(img, 0, 255).astype('uint8')
    return img


def display_image(image):
    if len(image.shape) == 4:
        img = np.squeeze(image, axis=0)

    img = deprocess(img)

    plt.grid(False)
    plt.xticks([]) #Removes axis numbers and ticks
    plt.yticks([])
    plt.imshow(img)
    return

# %%
content_img = load_and_process_image("/content/panting.jpeg")
display_image(content_img)

style_img = load_and_process_image("/content/panting.jpeg")
display_image(style_img)

# %%
#Step 3: Model Initialization
model = VGG19(
    include_top=False, #Keeps only convolutional layers
    weights='imagenet'
)

model.trainable = False #We are not training VGG19, We only use it as a feature extractor

model.summary()
# Out:
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
#Step 4: Content Model defining, We choose a deep CNN layer that understands image content.
content_layer = 'block5_conv2'
content_model = Model(
    inputs=model.input,
    outputs=model.get_layer(content_layer).output
)
content_model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,304,768 (58.38 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 15,304,768 (58.38 MB)

# %%
#Step 5: Style Model defining:
style_layers = [
    'block1_conv1',
    'block3_conv1',
    'block5_conv1'
]
style_models = [Model(inputs=model.input,
                      outputs=model.get_layer(layer).output) for layer in style_layers]

# %%
#Content Loss
def content_loss(content, generated):
    a_C = content_model(content)
    a_G = content_model(generated)  # Add this line to compute a_G
    loss = tf.reduce_mean(tf.square(a_C - a_G))
    return loss

# %%
#Gran Matrix
def gram_matrix(A):
    channels = int(A.shape[-1])
    a = tf.reshape(A, [-1, channels])
    n = tf.shape(a)[0]
    gram = tf.matmul(a, a, transpose_a=True)
    return gram / tf.cast(n, tf.float32)


weight_of_layer = 1. / len(style_models)

# %%
#Style Loss
def style_cost(style, generated):
    J_style = 0

    for style_model in style_models:
        a_S = style_model(style)
        a_G = style_model(generated)
        GS = gram_matrix(a_S)
        GG = gram_matrix(a_G)
        content_cost = tf.reduce_mean(tf.square(GS - GG))
        J_style += content_cost * weight_of_layer

    return J_style

# %%
#Content Loss
def content_cost(style, generated):
    J_content = 0

    for style_model in style_models:
        a_S = style_model(style)
        a_G = style_model(generated)
        GS = gram_matrix(a_S)
        GG = gram_matrix(a_G)
        content_cost = tf.reduce_mean(tf.square(GS - GG))
        J_content += content_cost * weight_of_layer

    return J_content

# %%
#Training Function
generated_images = []


def training_loop(content_path, style_path, iterations=50, a=20, b=1000):

    content = load_and_process_image(content_path)
    style = load_and_process_image(style_path)
    generated = tf.Variable(content, dtype=tf.float32)

    opt = tf.keras.optimizers.Adam(learning_rate=0.7)

    best_cost = math.inf
    best_image = None
    for i in range(iterations):
        start_time_cpu = time.process_time()
        start_time_wall = time.time()
        with tf.GradientTape() as tape:
            J_content = content_cost(style, generated)
            J_style = style_cost(style, generated)
            J_total = a * J_content + b * J_style

        grads = tape.gradient(J_total, generated)
        opt.apply_gradients([(grads, generated)])

        end_time_cpu = time.process_time()
        end_time_wall = time.time()
        cpu_time = end_time_cpu - start_time_cpu
        wall_time = end_time_wall - start_time_wall

        if J_total < best_cost:
            best_cost = J_total
            best_image = generated.numpy()

        print("CPU times: user {} µs, sys: {} ns, total: {} µs".format(
          int(cpu_time * 1e6),
          int(( end_time_cpu - start_time_cpu) * 1e9),
          int((end_time_cpu - start_time_cpu + 1e-6) * 1e6))
             )

        print("Wall time: {:.2f} µs".format(wall_time * 1e6))
        print("Iteration :{}".format(i))
        print('Total Loss {:e}.'.format(J_total))
        generated_images.append(generated.numpy())

    return best_image

# %%
final_img = training_loop("/content/dog.jpeg", "/content/panting.jpeg")
# Out:
# CPU times: user 265620 µs, sys: 265620972 ns, total: 265621 µs
# Wall time: 266761.06 µs
# Iteration :0
# Total Loss 2.470225e+11.
# CPU times: user 256656 µs, sys: 256656139 ns, total: 256657 µs
# Wall time: 257222.41 µs
# Iteration :1
# Total Loss 2.208906e+11.
# CPU times: user 261360 µs, sys: 261360129 ns, total: 261361 µs
# Wall time: 261850.83 µs
# Iteration :2
# Total Loss 2.016740e+11.
# CPU times: user 251842 µs, sys: 251842620 ns, total: 251843 µs
# Wall time: 257692.81 µs
# Iteration :3
# Total Loss 1.863415e+11.
# CPU times: user 256258 µs, sys: 256258762 ns, total: 256259 µs
# Wall time: 257205.49 µs
# Iteration :4
# Total Loss 1.733937e+11.
# CPU times: user 255061 µs, sys: 255061748 ns, total: 255062 µs
# Wall time: 256099.46 µs
# Iteration :5
# Total Loss 1.619656e+11.
# CPU times: user 264926 µs, sys: 264926512 ns, total: 264927 µs
# Wall time: 265864.85 µs
# Iteration :6
# Total Loss 1.516467e+11.
# CPU times: user 252309 µs, sys: 252309840 ns, total: 252310 µs
# Wall time: 252874.14 µs
# Iteration :7
# Total Loss 1.422300e+11.
# CPU times: user 253423 µs, sys: 253423662 ns, total: 253424 µs
# Wall time: 254427.67 µs
# Iteration :8
# Total Loss 1.335906e+11.
# CPU times: user 357866 µs, sys: 357866352 ns, total: 357867 µs
# Wall time: 374245.88 µs
# Iteration :9
# Total Loss 1.257659e+11.
# CPU times: user 339699 µs, sys: 339699861 ns, total: 339700 µs
# Wall time: 343113.66 µs
# Iteration :10
# Total Loss 1.187333e+11.
# CPU times: user 339791 µs, sys: 339791161 ns, total: 339792 µs
# Wall time: 352846.38 µs
# Iteration :11
# Total Loss 1.124907e+11.
# CPU times: user 343152 µs, sys: 343152193 ns, total: 343153 µs
# Wall time: 360000.61 µs
# Iteration :12
# Total Loss 1.070404e+11.
# CPU times: user 364261 µs, sys: 364261642 ns, total: 364262 µs
# Wall time: 374642.37 µs
# Iteration :13
# Total Loss 1.023392e+11.
# CPU times: user 311784 µs, sys: 311784816 ns, total: 311785 µs
# Wall time: 313310.86 µs
# Iteration :14
# Total Loss 9.830189e+10.
# CPU times: user 266544 µs, sys: 266544107 ns, total: 266545 µs
# Wall time: 266972.30 µs
# Iteration :15
# Total Loss 9.479968e+10.
# CPU times: user 256420 µs, sys: 256420819 ns, total: 256421 µs
# Wall time: 256942.03 µs
# Iteration :16
# Total Loss 9.170104e+10.
# CPU times: user 256860 µs, sys: 256860551 ns, total: 256861 µs
# Wall time: 258167.51 µs
# Iteration :17
# Total Loss 8.885966e+10.
# CPU times: user 250518 µs, sys: 250518562 ns, total: 250519 µs
# Wall time: 251142.26 µs
# Iteration :18
# Total Loss 8.615834e+10.
# CPU times: user 265867 µs, sys: 265867481 ns, total: 265868 µs
# Wall time: 267098.43 µs
# Iteration :19
# Total Loss 8.353085e+10.
# CPU times: user 258882 µs, sys: 258882654 ns, total: 258883 µs
# Wall time: 259467.36 µs
# Iteration :20
# Total Loss 8.094643e+10.
# CPU times: user 252802 µs, sys: 252802929 ns, total: 252803 µs
# Wall time: 252935.41 µs
# Iteration :21
# Total Loss 7.840004e+10.
# CPU times: user 262920 µs, sys: 262920185 ns, total: 262921 µs
# Wall time: 266560.32 µs
# Iteration :22
# Total Loss 7.589380e+10.
# CPU times: user 259377 µs, sys: 259377316 ns, total: 259378 µs
# Wall time: 260793.69 µs
# Iteration :23
# Total Loss 7.343622e+10.
# CPU times: user 250860 µs, sys: 250860965 ns, total: 250861 µs
# Wall time: 251536.37 µs
# Iteration :24
# Total Loss 7.102899e+10.
# CPU times: user 251628 µs, sys: 251628154 ns, total: 251629 µs
# Wall time: 251902.34 µs
# Iteration :25
# Total Loss 6.867978e+10.
# CPU times: user 265400 µs, sys: 265400249 ns, total: 265401 µs
# Wall time: 266072.75 µs
# Iteration :26
# Total Loss 6.638824e+10.
# CPU times: user 278212 µs, sys: 278212779 ns, total: 278213 µs
# Wall time: 278652.91 µs
# Iteration :27
# Total Loss 6.417603e+10.
# CPU times: user 261565 µs, sys: 261565195 ns, total: 261566 µs
# Wall time: 262563.94 µs
# Iteration :28
# Total Loss 6.204905e+10.
# CPU times: user 263053 µs, sys: 263053792 ns, total: 263054 µs
# Wall time: 264170.17 µs
# Iteration :29
# Total Loss 6.001897e+10.
# CPU times: user 261189 µs, sys: 261189269 ns, total: 261190 µs
# Wall time: 262533.66 µs
# Iteration :30
# Total Loss 5.809263e+10.
# CPU times: user 257342 µs, sys: 257342287 ns, total: 257343 µs
# Wall time: 258048.30 µs
# Iteration :31
# Total Loss 5.628057e+10.
# CPU times: user 252061 µs, sys: 252061851 ns, total: 252062 µs
# Wall time: 252724.41 µs
# Iteration :32
# Total Loss 5.458301e+10.
# CPU times: user 264115 µs, sys: 264115619 ns, total: 264116 µs
# Wall time: 264762.16 µs
# Iteration :33
# Total Loss 5.299597e+10.
# CPU times: user 260232 µs, sys: 260232182 ns, total: 260233 µs
# Wall time: 261431.46 µs
# Iteration :34
# Total Loss 5.150853e+10.
# CPU times: user 253405 µs, sys: 253405434 ns, total: 253406 µs
# Wall time: 254308.94 µs
# Iteration :35
# Total Loss 5.010783e+10.
# CPU times: user 256678 µs, sys: 256678048 ns, total: 256679 µs
# Wall time: 257356.64 µs
# Iteration :36
# Total Loss 4.877826e+10.
# CPU times: user 258066 µs, sys: 258066030 ns, total: 258067 µs
# Wall time: 259003.16 µs
# Iteration :37
# Total Loss 4.750793e+10.
# CPU times: user 254423 µs, sys: 254423223 ns, total: 254424 µs
# Wall time: 255016.33 µs
# Iteration :38
# Total Loss 4.628589e+10.
# CPU times: user 253296 µs, sys: 253296568 ns, total: 253297 µs
# Wall time: 254024.51 µs
# Iteration :39
# Total Loss 4.511048e+10.
# CPU times: user 266149 µs, sys: 266149910 ns, total: 266150 µs
# Wall time: 266691.21 µs
# Iteration :40
# Total Loss 4.397897e+10.
# CPU times: user 259085 µs, sys: 259085706 ns, total: 259086 µs
# Wall time: 260281.56 µs
# Iteration :41
# Total Loss 4.289346e+10.
# CPU times: user 432143 µs, sys: 432143523 ns, total: 432144 µs
# Wall time: 432571.41 µs
# Iteration :42
# Total Loss 4.185126e+10.
# CPU times: user 267483 µs, sys: 267483169 ns, total: 267484 µs
# Wall time: 270350.69 µs
# Iteration :43
# Total Loss 4.085477e+10.
# CPU times: user 255346 µs, sys: 255346611 ns, total: 255347 µs
# Wall time: 255872.96 µs
# Iteration :44
# Total Loss 3.990080e+10.
# CPU times: user 263811 µs, sys: 263811827 ns, total: 263812 µs
# Wall time: 265990.26 µs
# Iteration :45
# Total Loss 3.898537e+10.
# CPU times: user 263930 µs, sys: 263930191 ns, total: 263931 µs
# Wall time: 266797.30 µs
# Iteration :46
# Total Loss 3.810598e+10.
# CPU times: user 259157 µs, sys: 259157992 ns, total: 259158 µs
# Wall time: 260765.31 µs
# Iteration :47
# Total Loss 3.726017e+10.
# CPU times: user 344735 µs, sys: 344735638 ns, total: 344736 µs
# Wall time: 374156.24 µs
# Iteration :48
# Total Loss 3.644725e+10.
# CPU times: user 339307 µs, sys: 339307525 ns, total: 339308 µs
# Wall time: 354295.49 µs
# Iteration :49
# Total Loss 3.566788e+10.

# %%
plt.figure(figsize=(9, 9))


display_image(final_img)
